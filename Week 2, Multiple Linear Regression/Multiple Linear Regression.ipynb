# %% [markdown]
# # ASIGNMENT #1

# %%
import pandas as pd
dtype_dict = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int}
House_Data=pd.read_csv('kc_house_data.csv', sep=',',dtype=dtype_dict)
House_Train_Data=pd.read_csv('kc_house_train_data.csv', sep=',', dtype=dtype_dict)
House_Test_Data=pd.read_csv('kc_house_test_data.csv',sep=',',dtype=dtype_dict)
House_Data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608  0263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611  0291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot floors  waterfront  view  ...  grade  sqft_above  \
# 0           1180.0      5650      1           0     0  ...      7        1180
# ...

# %% [markdown]
# ## Adding Data

# %%
import math
def sq(Data):
    return Data*Data
House_Data['bedrooms_sq']=House_Data['bedrooms'].apply(sq)
House_Test_Data['bedrooms_sq']=House_Test_Data['bedrooms'].apply(sq)
House_Train_Data['bedrooms_sq']=House_Train_Data['bedrooms'].apply(sq)
House_Test_Data
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 0     0114101516  20140528T000000   310000.0       3.0       1.00
# 1     9297300055  20150124T000000   650000.0       4.0       3.00
# 2     1202000200  20141103T000000   233000.0       3.0       2.00
# 3     8562750320  20141110T000000   580500.0       3.0       2.50
# 4     7589200193  20141110T000000   535000.0       3.0       1.00
# ...          ...              ...        ...       ...        ...
# 4224  8672200110  20150317T000000  1088000.0       5.0       3.75
# 4225  5087900040  20141017T000000   350000.0       4.0       2.75
# 4226  3448900210  20141014T000000   610685.0       4.0       2.50
# 4227  6600060120  20150223T000000   400000.0       4.0       2.50
# 4228  1523300141  20140623T000000   402101.0       2.0       0.75
#
#       sqft_living  sqft_lot floors  waterfront  view  ...  yr_renovated  \
# 0          1430.0     19901    1.5           0     0  ...             0
# ...

# %%
House_Data['bed_bath_rooms']=House_Data['bedrooms']*House_Data['bathrooms']
House_Test_Data['bed_bath_rooms']=House_Test_Data['bedrooms']*House_Test_Data['bathrooms']
House_Train_Data['bed_bath_rooms']=House_Train_Data['bedrooms']*House_Train_Data['bathrooms']
House_Train_Data
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0       3.0       1.00
# 1      6414100192  20141209T000000   538000.0       3.0       2.25
# 2      5631500400  20150225T000000   180000.0       2.0       1.00
# 3      2487200875  20141209T000000   604000.0       4.0       3.00
# 4      1954400510  20150218T000000   510000.0       3.0       2.00
# ...           ...              ...        ...       ...        ...
# 17379  7936000429  20150326T000000  1007500.0       4.0       3.50
# 17380  2997800021  20150219T000000   475000.0       3.0       2.50
# 17381  0263000018  20140521T000000   360000.0       3.0       2.50
# 17382  0291310100  20150116T000000   400000.0       3.0       2.50
# 17383  1523300157  20141015T000000   325000.0       2.0       0.75
#
#        sqft_living  sqft_lot floors  waterfront  view  ...  yr_renovated  \
# 0           1180.0      5650      1           0     0  ...             0
# ...

# %%
House_Data['Log_Sqft_Living']=House_Data['sqft_living'].apply(math.log)
House_Test_Data['Log_Sqft_Living']=House_Test_Data['sqft_living'].apply(math.log)
House_Train_Data['Log_Sqft_Living']=House_Train_Data['sqft_living'].apply(math.log)
House_Test_Data
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 0     0114101516  20140528T000000   310000.0       3.0       1.00
# 1     9297300055  20150124T000000   650000.0       4.0       3.00
# 2     1202000200  20141103T000000   233000.0       3.0       2.00
# 3     8562750320  20141110T000000   580500.0       3.0       2.50
# 4     7589200193  20141110T000000   535000.0       3.0       1.00
# ...          ...              ...        ...       ...        ...
# 4224  8672200110  20150317T000000  1088000.0       5.0       3.75
# 4225  5087900040  20141017T000000   350000.0       4.0       2.75
# 4226  3448900210  20141014T000000   610685.0       4.0       2.50
# 4227  6600060120  20150223T000000   400000.0       4.0       2.50
# 4228  1523300141  20140623T000000   402101.0       2.0       0.75
#
#       sqft_living  sqft_lot floors  waterfront  view  ...  yr_renovated  \
# 0          1430.0     19901    1.5           0     0  ...             0
# ...

# %%
House_Data['Lat_Plus_Long']=House_Data['lat']+House_Data['long']
House_Test_Data['Lat_Plus_Long']=House_Test_Data['lat']+House_Test_Data['long']
House_Train_Data['Lat_Plus_Long']=House_Train_Data['lat']+House_Train_Data['long']
House_Test_Data
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 0     0114101516  20140528T000000   310000.0       3.0       1.00
# 1     9297300055  20150124T000000   650000.0       4.0       3.00
# 2     1202000200  20141103T000000   233000.0       3.0       2.00
# 3     8562750320  20141110T000000   580500.0       3.0       2.50
# 4     7589200193  20141110T000000   535000.0       3.0       1.00
# ...          ...              ...        ...       ...        ...
# 4224  8672200110  20150317T000000  1088000.0       5.0       3.75
# 4225  5087900040  20141017T000000   350000.0       4.0       2.75
# 4226  3448900210  20141014T000000   610685.0       4.0       2.50
# 4227  6600060120  20150223T000000   400000.0       4.0       2.50
# 4228  1523300141  20140623T000000   402101.0       2.0       0.75
#
#       sqft_living  sqft_lot floors  waterfront  view  ...  yr_renovated  \
# 0          1430.0     19901    1.5           0     0  ...             0
# ...

# %% [markdown]
# ## Calculating the Mean of the Added Data

# %%
print('The mean of Sq. Bedrooms: {}'.format(House_Test_Data['bedrooms_sq'].mean()))
print('The mean of bed * bath: {}'.format(House_Test_Data['bed_bath_rooms'].mean()))
print('The mean of the log of sqft: {}'.format(House_Test_Data['Log_Sqft_Living'].mean()))
print('The mean of Lat + Long: {}'.format(House_Test_Data['Lat_Plus_Long'].mean()))
# Out:
# The mean of Sq. Bedrooms: 12.4466777015843
# The mean of bed * bath: 7.5039016315913925
# The mean of the log of sqft: 7.550274679645921
# The mean of Lat + Long: -74.65333355403185

# %% [markdown]
# ## Separating the Features for the Models

# %%
ft1=['sqft_living','bedrooms','bathrooms','lat','long']
ft2=['sqft_living','bedrooms','bathrooms','lat','long','bed_bath_rooms']
ft3=['sqft_living','bedrooms','bathrooms','lat','long','bed_bath_rooms','bedrooms_sq','Log_Sqft_Living','Lat_Plus_Long']
x1=House_Data[ft1]
x2=House_Data[ft2]
x3=House_Data[ft3]
y=House_Data['price']
x1_train=House_Train_Data[ft1]
x2_train=House_Train_Data[ft2]
x3_train=House_Train_Data[ft3]
y_train=House_Train_Data['price']
x1_test=House_Test_Data[ft1]
x2_test=House_Test_Data[ft2]
x3_test=House_Test_Data[ft3]
y_test=House_Test_Data['price']

# %% [markdown]
# ## Applying Models and Finding Coefficients

# %%
from sklearn.linear_model import LinearRegression
Model1=LinearRegression()
Model1.fit(x1_train,y_train)
coef_1=pd.DataFrame(Model1.coef_, x1.columns, columns=['Coefficient'])
coef_1
# Out:
#                Coefficient
# sqft_living     312.258646
# bedrooms     -59586.533154
# bathrooms     15706.742083
# lat          658619.263931
# long        -309374.351268

# %%
Model2=LinearRegression()
Model2.fit(x2_train,y_train)
coef_2=pd.DataFrame(Model2.coef_,x2.columns,columns=['Coefficient'])
coef_2
# Out:
#                   Coefficient
# sqft_living        306.610053
# bedrooms       -113446.368070
# bathrooms       -71461.308293
# lat             654844.629503
# long           -294298.969138
# bed_bath_rooms   25579.652001

# %%
Model3=LinearRegression()
Model3.fit(x3_train,y_train)
coef_3=pd.DataFrame(Model3.coef_,x3.columns,columns=['Coefficient'])
coef_3
# Out:
#                    Coefficient
# sqft_living         529.422820
# bedrooms          34514.229578
# bathrooms         67060.781319
# lat              534085.610867
# long            -406750.710861
# bed_bath_rooms    -8570.504395
# bedrooms_sq       -6788.586670
# Log_Sqft_Living -561831.484076
# Lat_Plus_Long    127334.900006

# %% [markdown]
# ## ROOT SUM OF SQUARES TRAIN

# %%
RSS1_train=((Model1.predict(x1_train)-y_train)**2).sum()
RSS2_train=((Model2.predict(x2_train)-y_train)**2).sum()
RSS3_train=((Model3.predict(x3_train)-y_train)**2).sum()
print('RSS1: {}'.format(RSS1_train))
print('RSS2: {}'.format(RSS2_train))
print('RSS3: {}'.format(RSS3_train))
# Out:
# RSS1: 967879963049545.8
# RSS2: 958419635074070.0
# RSS3: 903436455050479.2

# %% [markdown]
# ## ROOT SUM OF SQUARES TEST

# %%
RSS1_test=((Model1.predict(x1_test)-y_test)**2).sum()
RSS2_test=((Model2.predict(x2_test)-y_test)**2).sum()
RSS3_test=((Model3.predict(x3_test)-y_test)**2).sum()
print('RSS1: {}'.format(RSS1_test))
print('RSS2: {}'.format(RSS2_test))
print('RSS3: {}'.format(RSS3_test))
# Out:
# RSS1: 225500469795490.34
# RSS2: 223377462976467.5
# RSS3: 259236319207179.94

# %% [markdown]
# # ASSIGNMENT #2

# %% [markdown]
# ## Converting to a Numpy

# %%
import numpy as np
def get_numpy_data(dataframe, features, output):
    dataframe['constant'] = 1 # add a constant column to a DataFrame
    # prepend variable 'constant' to the features list
    features = ['constant'] + features
    # select the columns of DataFrame given by the ‘features’ list into the DataFrame ‘features_Dataframe’
    features_Dataframe=dataframe[features]
    # this will convert the features_sframe into a numpy matrix:
    features_matrix = features_Dataframe.to_numpy()
    # assign the column of data_sframe associated with the target to the variable ‘output_sarray’
    output_darray = dataframe[output]
    # this will convert the SArray into a numpy array:
    output_array = output_darray.to_numpy()
    return(features_matrix, output_array)

# %%
(example_features, example_output) = get_numpy_data(House_Data, ['sqft_living'], 'price')
print(example_features)
print(example_output)
print(type(example_features))
# Out:
# [[1.00e+00 1.18e+03]
#  [1.00e+00 2.57e+03]
#  [1.00e+00 7.70e+02]
#  ...
#  [1.00e+00 1.02e+03]
#  [1.00e+00 1.60e+03]
#  [1.00e+00 1.02e+03]]
# [221900. 538000. 180000. ... 402101. 400000. 325000.]
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Predicting Output Given The Regression Weights

# %%
def predict_output(feature_matrix, weights):
    predictions = np.dot(feature_matrix, weights)
    return(predictions)
weigths=np.array([1,1])
test_predictions = predict_output(example_features, weights)
print(test_predictions[0])
print(test_predictions[1])
# Out:
# 1181.0
# 2571.0

# %% [markdown]
# ## Calculating the Derivative

# %%
def feature_derivative(errors, feature):
    derivative = 2*np.dot(errors, feature)
    return(derivative)
errors=test_predictions-example_output
features=example_features
derivative=feature_derivative(errors,features)
print(derivative)
# Out:
# [-2.32559010e+10 -5.85652694e+13]

# %%
print(example_output)
print(errors)
print(features)
# Out:
# [221900. 538000. 180000. ... 402101. 400000. 325000.]
# [-220719. -535429. -179229. ... -401080. -398399. -323979.]
# [[1.00e+00 1.18e+03]
#  [1.00e+00 2.57e+03]
#  [1.00e+00 7.70e+02]
#  ...
#  [1.00e+00 1.02e+03]
#  [1.00e+00 1.60e+03]
#  [1.00e+00 1.02e+03]]

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(feature_matrix, output, initial_weights, step_size, tolerance):
    converged = False 
    weights = np.array(initial_weights)
    while not converged:
        predictions = predict_output(feature_matrix, weights)
        errors = predictions - output
        gradient_sum_squares = 0
        for i in range(len(weights)): 
            derivative = feature_derivative(errors, feature_matrix[:, i])
            gradient_sum_squares += (derivative**2)
            weights[i] -= (step_size * derivative)
        gradient_magnitude = math.sqrt(gradient_sum_squares)
        if gradient_magnitude < tolerance:
            converged = True
    return(weights)

# %% [markdown]
# ### Using the Train Data

# %%
simple_features = ['sqft_living']
output = 'price'
(simple_feature_matrix, train_output) = get_numpy_data(House_Train_Data, simple_features, output)
initial_weights = np.array([-47000., 1.])
step_size = 7e-12
tolerance = 2.5e7

# %%
test_weight = gradient_descent(simple_feature_matrix, train_output, initial_weights, step_size, tolerance)
print(test_weight)
# Out:
# [-46999.88716555    281.91211918]

# %% [markdown]
# ### Using the Test Data

# %%
(test_simple_feature_matrix, test_output) = get_numpy_data(House_Test_Data, simple_features, output)
test_predictions = predict_output(test_simple_feature_matrix, test_weight)
print(test_predictions)
# Out:
# [356134.443255   784640.86440132 435069.83662406 ... 663418.65315598
#  604217.10812919 240550.47439317]

# %%
test_predictions[0]
# Out:
# 356134.4432550024

# %%
test_residuals = test_output - test_predictions
test_RSS = (test_residuals * test_residuals).sum()
test_RSS
# Out:
# 275400044902128.3

# %% [markdown]
# ## Running Multiple Regression

# %% [markdown]
# ### Train Data

# %%
model_features = ['sqft_living', 'sqft_living15']
my_output = 'price'
(feature_matrix, output) = get_numpy_data(House_Train_Data, model_features, my_output)
initial_weights = np.array([-100000., 1., 1.])
step_size = 4e-12
tolerance = 1e9

# %%
weight_2 = gradient_descent(feature_matrix, output, initial_weights, step_size, tolerance)
weight_2
# Out:
# array([-9.99999688e+04,  2.45072603e+02,  6.52795267e+01])

# %% [markdown]
# ### Test Data

# %%
(test_feature_matrix, test_output) = get_numpy_data(House_Test_Data, model_features, my_output)

test_predictions_2 = predict_output(test_feature_matrix, weight_2)
test_predictions_2
# Out:
# array([366651.41162949, 762662.39850726, 386312.09557541, ...,
#        682087.39916306, 585579.27901327, 216559.20391786])

# %%
test_predictions_2[0]
# Out:
# 366651.4116294939

# %%
House_Test_Data['price'][0]
# Out:
# 310000.0

# %%
test_residuals_2 = test_output - test_predictions_2
test_RSS_2 = (test_residuals_2**2).sum()
test_RSS_2
# Out:
# 270263443629803.56
